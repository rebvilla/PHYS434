# %%
#Rebecca Xu, PHYS 434 Lab 3

# %%
# %matplotlib inline
import matplotlib
import numpy as np 
import matplotlib.pyplot as plt 
import scipy
from scipy import stats
plt.rcParams["figure.figsize"] = (20,15)

# %%
#Problem 1
#A.

d = stats.norm.rvs(loc=12, scale=0.4, size=100000, random_state=None)
d_1 = np.append(d, [10., 10.3, 2.1, 0., 0., 15.6, 22.3, 12.7])
print(d_1)
fig, ax = plt.subplots(1, 1)
ax.hist(d_1,100008, density=True)
#matplotlib.pyplot.step(np.arange(0, 25, 25/100008), d_1)
# Out:
# [11.97035138 12.83360905 12.13980197 ... 15.6        22.3
#  12.7       ]
# (array([0.0896861 , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.04484305]),
#  array([0.00000000e+00, 2.22982161e-04, 4.45964323e-04, ...,
#         2.22995540e+01, 2.22997770e+01, 2.23000000e+01]),
#  <a list of 100008 Patch objects>)

# %%
#Question: 
#Math question: How many data points fall into the four categories of the truth table? (True Pos = good, False Neg = bad)

# %%
#Problem 2
#Question: For the asteroid to be detected, what is its distance in arcseconds?
#Question in math: What is the pdf here that would make the significance be 5 sigma?

# %%
#Problem 3
